# %%
# IMPORTING LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt # this library is used to represent data in graphical form
import pandas as pd

# %%
#IMPORTING THE DATASET

# %%
file=pd.read_excel("C:/Users/Shubham/Downloads/Marketing Data Google Ads 6th june.xlsx")

# %%
file
# Out:
#        Sr no  Impressions       Clicks  Sales Unit
# 0   00:00:00        258647   7759.4100   54.315870
# 1   00:30:00        219974   8798.9600   61.592720
# 2   01:00:00          1096     10.9600    0.076720
# 3   01:30:00          1481     14.8100    0.103670
# 4   02:00:00          1794     17.9400    0.125580
# 5   02:30:00          2156     21.5600    0.150920
# 6   03:00:00           413      4.1300    0.028910
# 7   03:30:00           144      1.4400    0.010080
# 8   04:00:00           139      1.3900    0.009730
# 9   04:30:00           191      1.9100    0.013370
# 10  05:00:00           396      3.9600    0.027720
# 11  05:30:00           274      2.7400    0.019180
# 12  06:00:00          3152     31.5200    0.220640
# 13  06:30:00          3089     30.8900    0.216230
# 14  07:00:00          2135     21.3500    0.149450
# 15  07:30:00         18498    369.9600    2.589720
# 16  08:00:00         17843    535.2900    3.747030
# ...

# %%
data=file.drop("Sr no",axis=1)

# %%
data
# Out:
#     Impressions       Clicks  Sales Unit
# 0         258647   7759.4100   54.315870
# 1         219974   8798.9600   61.592720
# 2           1096     10.9600    0.076720
# 3           1481     14.8100    0.103670
# 4           1794     17.9400    0.125580
# 5           2156     21.5600    0.150920
# 6            413      4.1300    0.028910
# 7            144      1.4400    0.010080
# 8            139      1.3900    0.009730
# 9            191      1.9100    0.013370
# 10           396      3.9600    0.027720
# 11           274      2.7400    0.019180
# 12          3152     31.5200    0.220640
# 13          3089     30.8900    0.216230
# 14          2135     21.3500    0.149450
# 15         18498    369.9600    2.589720
# 16         17843    535.2900    3.747030
# 17         12741    445.9350    3.121545
# 18         18973    683.0280    4.781196
# 19         11746    469.8400    3.288880
# 20         10967    219.3400    1.535380
# 21          8742    419.6160    2.937312
# ...

# %%
data.head()
# Out:
#    Impressions    Clicks  Sales Unit
# 0        258647  7759.41    54.31587
# 1        219974  8798.96    61.59272
# 2          1096    10.96     0.07672
# 3          1481    14.81     0.10367
# 4          1794    17.94     0.12558

# %%
# Discriptive Analysis

# %%
data.sum()
# Out:
# Impressions     2.207097e+06
# Clicks          8.431078e+04
# Sales Unit      5.901755e+02
# dtype: float64

# %%
# Impressions are indicating total visiblity of Ads on 6th june 23
# Total Impression are 2.207097e+06
# Clicks are indicating futher intrested audience for our Ads
# total Clicks are 8.431078e+04
# Sales Unit indicate total enrollment made in our products in every 30 min slot
# Total Sales Unit are  5.901755e+02

# %%
data.mean()
# Out:
# Impressions     45981.187500
# Clicks           1756.474554
# Sales Unit         12.295322
# dtype: float64

# %%
# The Average no of Impression are 45981.187500
# The Average no of Clicks are  1756.474554
# The Average no of Sales Unit are 12.295322

# %%
data.isnull().sum()
# Out:
# Impressions     0
# Clicks          0
# Sales Unit      0
# dtype: int64

# %%
x=data.iloc[:,1:-1].values
y=data.iloc[:,-1].values

# %%
x
# Out:
# array([[7.7594100e+03],
#        [8.7989600e+03],
#        [1.0960000e+01],
#        [1.4810000e+01],
#        [1.7940000e+01],
#        [2.1560000e+01],
#        [4.1300000e+00],
#        [1.4400000e+00],
#        [1.3900000e+00],
#        [1.9100000e+00],
#        [3.9600000e+00],
#        [2.7400000e+00],
#        [3.1520000e+01],
#        [3.0890000e+01],
#        [2.1350000e+01],
#        [3.6996000e+02],
#        [5.3529000e+02],
#        [4.4593500e+02],
#        [6.8302800e+02],
#        [4.6984000e+02],
#        [2.1934000e+02],
#        [4.1961600e+02],
#        [4.8708000e+01],
#        [4.1130000e+02],
#        [7.1009400e+02],
#        [6.7620300e+02],
#        [1.2399456e+03],
#        [2.0247200e+03],
#        [2.9193200e+03],
#        [5.3580000e+02],
#        [5.3580000e+01],
#        [4.4223000e+02],
#        [5.9019000e+02],
#        [4.2282400e+02],
#        [5.7720300e+02],
#        [3.7088400e+02],
#        [7.2012800e+02],
#        [1.9806500e+03],
# ...

# %%
y
# Out:
# array([5.43158700e+01, 6.15927200e+01, 7.67200000e-02, 1.03670000e-01,
#        1.25580000e-01, 1.50920000e-01, 2.89100000e-02, 1.00800000e-02,
#        9.73000000e-03, 1.33700000e-02, 2.77200000e-02, 1.91800000e-02,
#        2.20640000e-01, 2.16230000e-01, 1.49450000e-01, 2.58972000e+00,
#        3.74703000e+00, 3.12154500e+00, 4.78119600e+00, 3.28888000e+00,
#        1.53538000e+00, 2.93731200e+00, 3.40956000e-01, 2.87910000e+00,
#        4.97065800e+00, 4.73342100e+00, 8.67961920e+00, 1.41730400e+01,
#        2.04352400e+01, 3.75060000e+00, 3.75060000e-01, 3.09561000e+00,
#        4.13133000e+00, 2.95976800e+00, 4.04042100e+00, 2.59618800e+00,
#        5.04089600e+00, 1.38645500e+01, 1.44578000e+00, 1.99206000e+00,
#        7.90580000e-01, 1.11839000e+00, 1.37648000e+00, 1.67462400e+00,
#        3.86771700e+01, 5.70828720e+01, 9.01009200e+01, 1.60788264e+02])

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 0)

# %%
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR
# Out:
# LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=LR.predict(x_test)

# %%
y_predict
# Out:
# array([3.75060000e+00, 1.25580000e-01, 8.67961920e+00, 3.75060000e-01,
#        4.13133000e+00, 1.38645500e+01, 4.04042100e+00, 7.90580000e-01,
#        1.00800000e-02, 2.77200000e-02, 1.91800000e-02, 3.09561000e+00,
#        2.95976800e+00, 1.41730400e+01, 1.60788264e+02])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,LR.predict(x_train),color='blue')
plt.title('Impression vs Sales Unit (trainig set)')
plt.xlabel('Impression')
plt.ylabel('Sales Unit')
plt.show()

# %%
#conclusion

# %%
#From the graph we can conclude that the linear regression is giving perfect accuracy for advertisment data
